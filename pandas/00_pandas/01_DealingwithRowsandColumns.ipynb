# %%
# Import pandas package 
import pandas as pd 

# Define a dictionary containing employee data 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
		'Age':[27, 24, 22, 32], 
		'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'], 
		'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 

# Convert the dictionary into DataFrame 
df = pd.DataFrame(data) 

# select two columns 
print(df[['Name', 'Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
#coloumn addtion
# Import pandas package 
import pandas as pd 

# Define a dictionary containing Students data 
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'], 
		'Height': [5.1, 6.2, 5.1, 5.2], 
		'Qualification': ['Msc', 'MA', 'Msc', 'Msc']} 

# Convert the dictionary into DataFrame 
df = pd.DataFrame(data) 

# Declare a list that is to be converted into a column 
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna'] 

# Using 'Address' as the column name 
# and equating it to the list 
df['Address'] = address 

# Observe the result 
print(df)
# Out:
#      Name  Height Qualification    Address
# 0     Jai     5.1           Msc      Delhi
# 1  Princi     6.2            MA  Bangalore
# 2  Gaurav     5.1           Msc    Chennai
# 3    Anuj     5.2           Msc      Patna

# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for col in df.columns: 
    print(col)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
#rename columns in Pandas DataFrame
#Method #1: Using rename() function.\
df.rename(columns = {'Fare':'fare'}, inplace = True)

# %%
for col in df.columns: 
    print(col)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# fare
# Cabin
# Embarked

# %%
df.rename(columns={'fare':'Fare','Pclass':'pclass'},inplace = True)
df
# Out:
#      PassengerId  Survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for col in df.columns: 
    print(col)
# Out:
# PassengerId
# Survived
# pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
#drop one or multiple columns in Pandas
#Method #1: Drop Columns from a Dataframe using drop() method.
df.drop(['SibSp'], axis = 7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-83ce48504389> in <module>
#       1 #drop one or multiple columns in Pandas
#       2 #Method #1: Drop Columns from a Dataframe using drop() method.
# ----> 3 df.drop(['SibSp'], axis = 7)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3921             if index is not None or columns is not None:
#    3922                 raise ValueError("Cannot specify both 'labels' and 'index'/'columns'")
# ...

# %%
# Remove more than one columns as index base 
df.drop(df.columns[[5, 3, 1]], axis = 1, inplace = True) 
df

# %%
df.to_excel('tit.xlsx', sheet_name='sex', index=False)

# %%
#Get unique values from a column

#df.Name.unique()

# %%
#Apply uppercase to a column in Pandas dataframe

df['Name'] = df['Name'].str.upper()
df

# %%
Method #2: Using lambda with upper() method

df['Name'].apply(lambda x: x.upper()).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-db6482cff6ae> in <module>
# ----> 1 Method #2: Using lambda with upper() method
#       2
#       3 df['Name'].apply(lambda x: x.upper()).head(10)
#
# NameError: name 'Method' is not defined

# %%
#Capitalize first letter of a column
df['Name'] = df['Name'].str.capitalize() 
df
# Out:
#      PassengerId  Survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, mr. owen harris    male  22.0      1
# 1    Cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               Heikkinen, miss. laina  female  26.0      0
# 3         Futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             Allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Get n-largest values from a particular column
df.nlargest(5, ['Age'])
# Out:
#      PassengerId  Survived  pclass                                  Name  \
# 630          631         1       1  Barkworth, mr. algernon henry wilson
# 851          852         0       3                   Svensson, mr. johan
# 96            97         0       1             Goldschmidt, mr. george b
# 493          494         0       1               Artagaveytia, mr. ramon
# 116          117         0       3                  Connors, mr. patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
#Get n-smallest values from a particular column
df.nsmallest(5, ['Age'])
# Out:
#      PassengerId  Survived  pclass                             Name     Sex  \
# 803          804         1       3  Thomas, master. assad alexander    male
# 755          756         1       2        Hamalainen, master. viljo    male
# 469          470         1       3    Baclini, miss. helene barbara  female
# 644          645         1       3           Baclini, miss. eugenie  female
# 78            79         1       2    Caldwell, master. alden gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 469  0.75      2      1    2666  19.2583   NaN        C
# 644  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
total = df['Fare'].groupby(df['Sex']) 

print(total.mean())
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
#Ranking Rows of Pandas DataFrame
df['Rating_Rank'] = df['Fare'].rank(ascending = 1) 
  
# Set the index to newly created column, Rating_Rank 
df = df.set_index('Rating_Rank') 
print(df)
# Out:
#              PassengerId  Survived  pclass  \
# Rating_Rank
# 77.0                   1         0       3
# 789.0                  2         1       1
# 232.5                  3         1       3
# 748.0                  4         1       1
# 264.0                  5         0       3
# ...                  ...       ...     ...
# 407.5                887         0       2
# 654.5                888         1       1
# 546.5                889         0       3
# 654.5                890         1       1
# 123.5                891         0       3
#
#                                                           Name     Sex   Age  \
# Rating_Rank
# 77.0                                   Braund, mr. owen harris    male  22.0
# 789.0        Cumings, mrs. john bradley (florence briggs th...  female  38.0
# 232.5                                   Heikkinen, miss. laina  female  26.0
# 748.0             Futrelle, mrs. jacques heath (lily may peel)  female  35.0
# ...

# %%
df1 = df['Name'].str.contains("Thomas")
df1
# Out:
# Rating_Rank
# 77.0     False
# 789.0    False
# 232.5    False
# 748.0    False
# 264.0    False
#          ...
# 407.5    False
# 654.5    False
# 546.5    False
# 654.5    False
# 123.5    False
# Name: Name, Length: 891, dtype: bool
